# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from fbprophet import Prophet

# %%
f1=pd.read_csv('chicago_crime_2014.csv',error_bad_lines=False)
f2=pd.read_csv('chicago_crime_2015.csv',error_bad_lines=False)
f3=pd.read_csv('chicago_crime_2016.csv',error_bad_lines=False)

# %%
f=pd.concat([f1,f2,f3])

# %%
f.head()
# Out:
#         ID Case Number                    Date                   Block  IUCR  \
# 0  9446824    HX100141  01/01/2014 02:00:00 AM     0000X W ILLINOIS ST  0460
# 1  9446748    HX100020  01/01/2014 12:00:00 AM     006XX N DEARBORN ST  0890
# 2  9446758    HX100030  01/01/2014 12:30:00 AM        052XX W RACE AVE  1310
# 3  9446760    HX100027  01/01/2014 12:30:00 AM  053XX W WELLINGTON AVE  0460
# 4  9446764    HX100054  01/01/2014 12:10:00 AM    014XX W LEXINGTON ST  0460
#
#       Primary Type    Description Location Description  Arrest  Domestic  \
# 0          BATTERY         SIMPLE               STREET   False     False
# 1            THEFT  FROM BUILDING        BAR OR TAVERN   False     False
# 2  CRIMINAL DAMAGE    TO PROPERTY            APARTMENT   False     False
# 3          BATTERY         SIMPLE            APARTMENT    True     False
# 4          BATTERY         SIMPLE               STREET   False     False
#
#    Beat  District  Ward  Community Area FBI Code   Latitude  Longitude
# 0  1831        18  42.0             8.0      08B  41.890828 -87.630235
# 1  1832        18  42.0             8.0       06  41.893542 -87.629702
# 2  1523        15  28.0            25.0       14  41.890046 -87.756333
# 3  2514        25  31.0            19.0      08B  41.935011 -87.759739
# 4  1231        12  25.0            28.0      08B  41.872509 -87.663069

# %%
f1.shape
# Out:
# (274423, 17)

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,10))

# %%
sns.heatmap(f.isnull(),cbar=False,cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # visualize the data upper part which part has null value

# %%
f.head(3)
# Out:
#         ID Case Number                    Date                Block  IUCR  \
# 0  9446824    HX100141  01/01/2014 02:00:00 AM  0000X W ILLINOIS ST  0460
# 1  9446748    HX100020  01/01/2014 12:00:00 AM  006XX N DEARBORN ST  0890
# 2  9446758    HX100030  01/01/2014 12:30:00 AM     052XX W RACE AVE  1310
#
#       Primary Type    Description Location Description  Arrest  Domestic  \
# 0          BATTERY         SIMPLE               STREET   False     False
# 1            THEFT  FROM BUILDING        BAR OR TAVERN   False     False
# 2  CRIMINAL DAMAGE    TO PROPERTY            APARTMENT   False     False
#
#    Beat  District  Ward  Community Area FBI Code   Latitude  Longitude
# 0  1831        18  42.0             8.0      08B  41.890828 -87.630235
# 1  1832        18  42.0             8.0       06  41.893542 -87.629702
# 2  1523        15  28.0            25.0       14  41.890046 -87.756333

# %%
f.drop(['ID','Case Number','IUCR','Beat','District','Ward','Community Area','FBI Code','Latitude','Longitude'],axis=1)
# Out:
#                           Date                   Block     Primary Type  \
# 0       01/01/2014 02:00:00 AM     0000X W ILLINOIS ST          BATTERY
# 1       01/01/2014 12:00:00 AM     006XX N DEARBORN ST            THEFT
# 2       01/01/2014 12:30:00 AM        052XX W RACE AVE  CRIMINAL DAMAGE
# 3       01/01/2014 12:30:00 AM  053XX W WELLINGTON AVE          BATTERY
# 4       01/01/2014 12:10:00 AM    014XX W LEXINGTON ST          BATTERY
# ...                        ...                     ...              ...
# 217285  01/17/2016 12:00:00 PM    014XX N ARTESIAN AVE    OTHER OFFENSE
# 217286  01/16/2016 10:00:00 PM     012XX S WESTERN AVE    OTHER OFFENSE
# 217287  01/08/2016 11:10:00 AM      057XX S CICERO AVE            THEFT
# 217288  01/23/2016 01:00:00 AM      001XX S LEAVITT ST  CRIMINAL DAMAGE
# 217289  01/05/2016 09:00:00 AM    001XX S CAMPBELL AVE            THEFT
#
#                   Description  \
# 0                      SIMPLE
# 1               FROM BUILDING
# 2                 TO PROPERTY
# 3                      SIMPLE
# 4                      SIMPLE
# ...                       ...
# 217285  OTHER VEHICLE OFFENSE
# 217286  OTHER VEHICLE OFFENSE
# 217287          FROM BUILDING
# 217288             TO VEHICLE
# 217289         $500 AND UNDER
#
#                                    Location Description  Arrest  Domestic
# 0                                                STREET   False     False
# 1                                         BAR OR TAVERN   False     False
# 2                                             APARTMENT   False     False
# 3                                             APARTMENT    True     False
# 4                                                STREET   False     False
# ...                                                 ...     ...       ...
# 217285                                           STREET   False      True
# 217286                                           STREET   False     False
# 217287  AIRPORT BUILDING NON-TERMINAL - NON-SECURE AREA   False     False
# 217288                                           STREET   False     False
# 217289                         SCHOOL, PUBLIC, BUILDING   False     False
#
# [754541 rows x 7 columns]

# %% [markdown]
# #
